# %%
"""
Notebook to look at plots and gather some basic info for our analysis
"""

#libraries needed for loading tiff into plots
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#put our tiff into a variable

#load at school
#img = Image.open('/home/williamlavoy/model_traits/root_root_interaction_traits/2D_model_traits_work/images/test_classes.tiff')

#load at home
img = Image.open('/home/wlavoy/workDir/root_root_interaction_traits/2D_model_traits_work/images/test_classes.tiff')

# %%
#view our image
img.show()

#likely to be hard to view because of ilastik saves images
# Out:
# (eog:4550): Gtk-WARNING **: 10:29:12.455: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.

# %%
#put tiff into np array
img_array = np.array(img)

#plot array in plt
data = plt.imshow(img_array)

#draw the plot
plt.show()

# %%
#determine how large the array is so we can use for walker
print(img_array.shape)

# 3456 by 5184
# Out:
# (3456, 5184)

# %%
#look at different zones in the graph interactive vs non interactive root quadrants
#first zone
#plant 1: non interactive

#put tiff into np array
img_array = np.array(img)

#plot array in plt
data = plt.imshow(img_array).axes.set_xlim(0,1728)

#draw the plot
plt.show()

# %%
#look at different zones in the graph interactive vs non interactive root quadrants
#second zone
#plant 1 and 2: interactive

#put tiff into np array
img_array = np.array(img)

#plot array in plt
data = plt.imshow(img_array).axes.set_xlim(1728,3456)

#draw the plot
plt.show()

# %%
#look at different zones in the graph interactive vs non interactive root quadrants
#third zone
#plant 2: non interactive

#put tiff into np array
img_array = np.array(img)

#plot array in plt
data = plt.imshow(img_array).axes.set_xlim(3456,5184)

#draw the plot
plt.show()
